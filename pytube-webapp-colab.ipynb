# %% [markdown]
# # pytube-webapp
# A web-based front end for pytube

# %% [markdown]
# ## 1: Installation / Setup
#
# ### Clone repository & Install dependencies

# %%
# %cd /content/
# !git clone https://github.com/Nitro4542/pytube-webapp.git
# %cd pytube-webapp
# !pip install -r requirements-colab.txt

# %% [markdown]
# ### Install auth token
#
# Insert your ngrok token instead of "your_token".

# %%
# !ngrok authtoken your_token

# %% [markdown]
# # 3: Start website
#
# Start your website by running the main file for Colab.

# %%
# !python main-colab.py
